# %%
import pandas as pd
import numpy as np

# %%
import re
import nltk
import joblib

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from imblearn.over_sampling import SMOTE

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.metrics import accuracy_score , classification_report

# %%
from nltk.corpus import stopwords

# %%
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/keerthika/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/keerthika/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def preprocess_text(text):
    " " " Clean and Preprocess text data." " "
    if not isinstance(text,str):
        return ""
    text = text.lower()
    text = re.sub(r'[^a-zA-Z]', ' ',text)
    words = word_tokenize(text)
    words = [word for word in words if word not in stopwords.words('english')]
    return ''.join(words)

# %%
#Load dataset

# %%
data = {
    "resume": [
       "Experienced software engineer with expertise in Python, Java, and cloud computing.",
        "Data scientist skilled in machine learning, deep learning, and data visualization.",
        "Marketing specialist with experience in social media marketing and SEO.",
        "HR professional with experience in recruitment, employee relations, and compliance.",
        "Python developer with experience in Django, Flask, and backend systems.",
        "Machine learning engineer with expertise in neural networks and deep learning.",
        "Digital marketing expert in content creation and social media advertising.",
        "Human resources manager with experience in talent acquisition and training.",
        "Full-stack developer experienced in JavaScript, React, Node.js, and MongoDB.",
        "Business analyst with skills in data analysis, Power BI, and financial modeling.",
        "Cybersecurity analyst skilled in threat detection, penetration testing, and network security.",
        "Graphic designer with expertise in Adobe Photoshop, Illustrator, and branding.",
        "Sales executive with a strong background in lead generation and CRM management.",
        "AI researcher with experience in reinforcement learning and generative AI models."
    ],
    "category": ["Software Engineer", "Data Scientist", "Marketing", "HR",
        "Software Engineer", "Data Scientist", "Marketing", "HR",
        "Software Engineer", "Business Analyst", "Cybersecurity", "Graphic Designer",
        "Sales", "Data Scientist"]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                                resume           category
# 0   Experienced software engineer with expertise i...  Software Engineer
# 1   Data scientist skilled in machine learning, de...     Data Scientist
# 2   Marketing specialist with experience in social...          Marketing
# 3   HR professional with experience in recruitment...                 HR
# 4   Python developer with experience in Django, Fl...  Software Engineer
# 5   Machine learning engineer with expertise in ne...     Data Scientist
# 6   Digital marketing expert in content creation a...          Marketing
# 7   Human resources manager with experience in tal...                 HR
# 8   Full-stack developer experienced in JavaScript...  Software Engineer
# 9   Business analyst with skills in data analysis,...   Business Analyst
# 10  Cybersecurity analyst skilled in threat detect...      Cybersecurity
# 11  Graphic designer with expertise in Adobe Photo...   Graphic Designer
# 12  Sales executive with a strong background in le...              Sales
# 13  AI researcher with experience in reinforcement...     Data Scientist

# %%
df.dropna (inplace=True)

# %%
df= df[df['resume'].str.strip() != " "]

# %%
df['cleaned_resume']=df['resume'].apply(preprocess_text)

# %%
df['cleaned_resume']
# Out:
# 0     experiencedsoftwareengineerexpertisepythonjava...
# 1     datascientistskilledmachinelearningdeeplearnin...
# 2     marketingspecialistexperiencesocialmediamarket...
# 3     hrprofessionalexperiencerecruitmentemployeerel...
# 4     pythondeveloperexperiencedjangoflaskbackendsys...
# 5     machinelearningengineerexpertiseneuralnetworks...
# 6     digitalmarketingexpertcontentcreationsocialmed...
# 7     humanresourcesmanagerexperiencetalentacquisiti...
# 8     fullstackdeveloperexperiencedjavascriptreactno...
# 9     businessanalystskillsdataanalysispowerbifinanc...
# 10    cybersecurityanalystskilledthreatdetectionpene...
# 11    graphicdesignerexpertiseadobephotoshopillustra...
# 12    salesexecutivestrongbackgroundleadgenerationcr...
# 13    airesearcherexperiencereinforcementlearninggen...
# Name: cleaned_resume, dtype: object

# %%
df = pd.concat([df] * 3, ignore_index=True)

# %%
df
# Out:
#                                                resume           category  \
# 0   Experienced software engineer with expertise i...  Software Engineer
# 1   Data scientist skilled in machine learning, de...     Data Scientist
# 2   Marketing specialist with experience in social...          Marketing
# 3   HR professional with experience in recruitment...                 HR
# 4   Python developer with experience in Django, Fl...  Software Engineer
# 5   Machine learning engineer with expertise in ne...     Data Scientist
# 6   Digital marketing expert in content creation a...          Marketing
# 7   Human resources manager with experience in tal...                 HR
# 8   Full-stack developer experienced in JavaScript...  Software Engineer
# 9   Business analyst with skills in data analysis,...   Business Analyst
# 10  Cybersecurity analyst skilled in threat detect...      Cybersecurity
# 11  Graphic designer with expertise in Adobe Photo...   Graphic Designer
# 12  Sales executive with a strong background in le...              Sales
# 13  AI researcher with experience in reinforcement...     Data Scientist
# 14  Experienced software engineer with expertise i...  Software Engineer
# 15  Data scientist skilled in machine learning, de...     Data Scientist
# 16  Marketing specialist with experience in social...          Marketing
# 17  HR professional with experience in recruitment...                 HR
# 18  Python developer with experience in Django, Fl...  Software Engineer
# 19  Machine learning engineer with expertise in ne...     Data Scientist
# 20  Digital marketing expert in content creation a...          Marketing
# 21  Human resources manager with experience in tal...                 HR
# 22  Full-stack developer experienced in JavaScript...  Software Engineer
# 23  Business analyst with skills in data analysis,...   Business Analyst
# 24  Cybersecurity analyst skilled in threat detect...      Cybersecurity
# 25  Graphic designer with expertise in Adobe Photo...   Graphic Designer
# 26  Sales executive with a strong background in le...              Sales
# 27  AI researcher with experience in reinforcement...     Data Scientist
# 28  Experienced software engineer with expertise i...  Software Engineer
# 29  Data scientist skilled in machine learning, de...     Data Scientist
# 30  Marketing specialist with experience in social...          Marketing
# 31  HR professional with experience in recruitment...                 HR
# 32  Python developer with experience in Django, Fl...  Software Engineer
# 33  Machine learning engineer with expertise in ne...     Data Scientist
# 34  Digital marketing expert in content creation a...          Marketing
# 35  Human resources manager with experience in tal...                 HR
# 36  Full-stack developer experienced in JavaScript...  Software Engineer
# 37  Business analyst with skills in data analysis,...   Business Analyst
# 38  Cybersecurity analyst skilled in threat detect...      Cybersecurity
# 39  Graphic designer with expertise in Adobe Photo...   Graphic Designer
# 40  Sales executive with a strong background in le...              Sales
# 41  AI researcher with experience in reinforcement...     Data Scientist
#
#                                        cleaned_resume
# 0   experiencedsoftwareengineerexpertisepythonjava...
# 1   datascientistskilledmachinelearningdeeplearnin...
# 2   marketingspecialistexperiencesocialmediamarket...
# 3   hrprofessionalexperiencerecruitmentemployeerel...
# 4   pythondeveloperexperiencedjangoflaskbackendsys...
# 5   machinelearningengineerexpertiseneuralnetworks...
# 6   digitalmarketingexpertcontentcreationsocialmed...
# 7   humanresourcesmanagerexperiencetalentacquisiti...
# 8   fullstackdeveloperexperiencedjavascriptreactno...
# 9   businessanalystskillsdataanalysispowerbifinanc...
# 10  cybersecurityanalystskilledthreatdetectionpene...
# 11  graphicdesignerexpertiseadobephotoshopillustra...
# 12  salesexecutivestrongbackgroundleadgenerationcr...
# 13  airesearcherexperiencereinforcementlearninggen...
# 14  experiencedsoftwareengineerexpertisepythonjava...
# 15  datascientistskilledmachinelearningdeeplearnin...
# 16  marketingspecialistexperiencesocialmediamarket...
# 17  hrprofessionalexperiencerecruitmentemployeerel...
# 18  pythondeveloperexperiencedjangoflaskbackendsys...
# 19  machinelearningengineerexpertiseneuralnetworks...
# 20  digitalmarketingexpertcontentcreationsocialmed...
# 21  humanresourcesmanagerexperiencetalentacquisiti...
# 22  fullstackdeveloperexperiencedjavascriptreactno...
# 23  businessanalystskillsdataanalysispowerbifinanc...
# 24  cybersecurityanalystskilledthreatdetectionpene...
# 25  graphicdesignerexpertiseadobephotoshopillustra...
# 26  salesexecutivestrongbackgroundleadgenerationcr...
# 27  airesearcherexperiencereinforcementlearninggen...
# 28  experiencedsoftwareengineerexpertisepythonjava...
# 29  datascientistskilledmachinelearningdeeplearnin...
# 30  marketingspecialistexperiencesocialmediamarket...
# 31  hrprofessionalexperiencerecruitmentemployeerel...
# 32  pythondeveloperexperiencedjangoflaskbackendsys...
# 33  machinelearningengineerexpertiseneuralnetworks...
# 34  digitalmarketingexpertcontentcreationsocialmed...
# 35  humanresourcesmanagerexperiencetalentacquisiti...
# 36  fullstackdeveloperexperiencedjavascriptreactno...
# 37  businessanalystskillsdataanalysispowerbifinanc...
# 38  cybersecurityanalystskilledthreatdetectionpene...
# 39  graphicdesignerexpertiseadobephotoshopillustra...
# 40  salesexecutivestrongbackgroundleadgenerationcr...
# 41  airesearcherexperiencereinforcementlearninggen...

# %%
x = df['cleaned_resume']
y = df['category']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=8,random_state=42,stratify =y )

# %%
pipeline= Pipeline([
    ('vectorizer',TfidfVectorizer(max_features=5000,ngram_range=(1,2))),
    ('classifier',RandomForestClassifier(random_state=42))
])

# %%
param_grid= {
    'vectorizer__max_features' : [3000,5000],
    'vectorizer__ngram_range' : [(1,1),(1,2)],
    'classifier__n_estimators' : [100,200],
    'classifier__max_depth' : [3,10,None],
    'classifier__min_samples_split' : [5,10],
    'classifier__min_samples_leaf':[1,2]
}

# %%
grid_search = GridSearchCV(pipeline, param_grid, cv=2, n_jobs=-1,verbose=1)

# %%
print(Y_train.value_counts())
# Out:
# category
# Data Scientist       7
# Software Engineer    7
# HR                   5
# Marketing            5
# Graphic Designer     3
# Cybersecurity        3
# Sales                2
# Business Analyst     2
# Name: count, dtype: int64

# %%
grid_search.fit(X_train,Y_train)
# Out:
# Fitting 2 folds for each of 96 candidates, totalling 192 fits
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('vectorizer',
#                                         TfidfVectorizer(max_features=5000,
#                                                         ngram_range=(1, 2))),
#                                        ('classifier',
#                                         RandomForestClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'classifier__max_depth': [3, 10, None],
#                          'classifier__min_samples_leaf': [1, 2],
#                          'classifier__min_samples_split': [5, 10],
#                          'classifier__n_estimators': [100, 200],
#                          'vectorizer__max_features': [3000, 5000],
#                          'vectorizer__ngram_range': [(1, 1), (1, 2)]},
#              verbose=1)

# %%
best_model = grid_search.best_estimator_

# %%
#Save the model
joblib.dump(best_model,'resume_classifier.pkl')
# Out:
# ['resume_classifier.pkl']

# %%
pred = best_model.predict(X_test)

# %%
print(f"Model Accuracy: {accuracy_score(Y_test,pred):.4f}")

print(f"\nClassification Report: \n ", classification_report(Y_test,pred))
# Out:
# Model Accuracy: 1.0000
#
# Classification Report:
#                      precision    recall  f1-score   support
#
#  Business Analyst       1.00      1.00      1.00         1
#    Data Scientist       1.00      1.00      1.00         2
#                HR       1.00      1.00      1.00         1
#         Marketing       1.00      1.00      1.00         1
#             Sales       1.00      1.00      1.00         1
# Software Engineer       1.00      1.00      1.00         2
#
#          accuracy                           1.00         8
#         macro avg       1.00      1.00      1.00         8
#      weighted avg       1.00      1.00      1.00         8

# %%
def classify_resume(resume_text):
    model = joblib.load('resume_classifier.pkl')
    return model.predict([resume_text])[0]

# %%
new_resume = "AI researcher with experience in reinforcement learning and generative AI models."

# %%
print("Predicted category :" ,classify_resume(new_resume))
# Out:
# Predicted category : Data Scientist

# %%
new_resume = "Sales executive with a strong background in lead generation and CRM management."

# %%
print("Predicted category :", classify_resume(new_resume))
# Out:
# Predicted category : Software Engineer

# %%
new_resume = "Machine learning engineer with expertise in neural networks and deep learning."

# %%
print("Predicted category: ", classify_resume(new_resume))
# Out:
# Predicted category:  Data Scientist
